# %% [markdown]
# # Explory Data Analysis By Muhammad Zidan

# %% [markdown]
# ## 0. Importing dan Read Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
phone_sale=pd.read_csv('Phone_Sales.csv')

# %% [markdown]
# ## 1. Data Understanding

# %% [markdown]
# ### Bentuk Data

# %%
phone_sale.shape
# Out:
# (3114, 12)

# %% [markdown]
# ### Nama Kolom

# %%
phone_sale.columns
# Out:
# Index(['Brands', 'Models', 'Colors', 'Memory', 'Storage', 'Camera', 'Rating',
#        'Selling Price', 'Original Price', 'Mobile', 'Discount',
#        'discount percentage'],
#       dtype='object')

# %% [markdown]
# ### Meilihat Data Teratas

# %%
phone_sale.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %% [markdown]
# ### Melihat Data Terbawah

# %%
phone_sale.tail()
# Out:
#       Brands          Models     Colors Memory                Storage Camera  \
# 3109    POCO       M4 Pro 5G  Cool Blue   6 GB                 128 GB    Yes
# 3110   Nokia             225      Black    NaN  Expandable Upto 32 GB    Yes
# 3111   Apple      iPhone SE       White   2 GB                 128 GB    Yes
# 3112   Apple  iPhone 13 Pro        Gold   6 GB                 128 GB    Yes
# 3113  GIONEE             F9        Blue   3 GB                  32 GB    Yes
#
#       Rating  Selling Price  Original Price                Mobile  Discount  \
# 3109     4.4          16999           19999        POCO M4 Pro 5G      3000
# 3110     3.6           3499            3499             Nokia 225         0
# 3111     4.5          44900           44900      Apple iPhone SE          0
# 3112     NaN         119900          119900  Apple iPhone 13 Pro          0
# 3113     4.2           7900            7900            GIONEE F9          0
#
#       discount percentage
# ...

# %% [markdown]
# ### Type Data

# %%
phone_sale.dtypes
# Out:
# Brands                  object
# Models                  object
# Colors                  object
# Memory                  object
# Storage                 object
# Camera                  object
# Rating                 float64
# Selling Price            int64
# Original Price           int64
# Mobile                  object
# Discount                 int64
# discount percentage    float64
# dtype: object

# %% [markdown]
# ### Analisis Singkat

# %%
phone_sale.describe()
# Out:
#             Rating  Selling Price  Original Price      Discount  \
# count  2970.000000    3114.000000     3114.000000   3114.000000
# mean      4.243098   26436.625562    28333.473025   1896.847463
# std       0.271991   30066.892622    31525.599889   5337.126176
# min       2.300000    1000.000000     1000.000000  -8000.000000
# 25%       4.100000    9990.000000    10030.250000      0.000000
# 50%       4.300000   15000.000000    16889.500000      0.000000
# 75%       4.400000   28999.000000    31500.000000   2000.000000
# max       5.000000  179900.000000   189999.000000  75000.000000
#
#        discount percentage
# count          3114.000000
# mean              6.086788
# std              11.106776
# min            -160.320641
# 25%               0.000000
# 50%               0.000000
# 75%               9.836388
# max              70.610305

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### Column Drop

# %% [markdown]
# phone_sale.drop(['discount percentage'],axis=1,inplace=True)

# %%
phone_sale.columns
# Out:
# Index(['Brands', 'Models', 'Colors', 'Memory', 'Storage', 'Camera', 'Rating',
#        'Selling Price', 'Original Price', 'Mobile', 'Discount',
#        'discount percentage'],
#       dtype='object')

# %% [markdown]
# ### Duplicated Columns Checking

# %% [markdown]
# #### Duplicate by all Columns

# %%
phone_sale.loc[phone_sale.duplicated()]
# Out:
#        Brands           Models  Colors Memory                Storage Camera  \
# 16      Apple  iPhone 13 Mini     Pink   6 GB                 512 GB    Yes
# 178     Apple       iPhone 11    White    4GB                 256 GB    Yes
# 338     Nokia        C01 Plus     Blue   2 GB                  16 GB    Yes
# 765   SAMSUNG     Guru Music 2   Black    NaN                   2 MB    Yes
# 775     Apple        iPhone 7     Gold   2 GB                  32 GB    Yes
# ...       ...              ...     ...    ...                    ...    ...
# 3041    Apple       iPhone SE      Red   2 GB                 128 GB    Yes
# 3052    Apple       iPhone 11   Purple    4GB                 128 GB    Yes
# 3071    Apple        iPhone 7      Red   2 GB                 256 GB    Yes
# 3110    Nokia              225   Black    NaN  Expandable Upto 32 GB    Yes
# 3111    Apple       iPhone SE    White   2 GB                 128 GB    Yes
#
# ...

# %% [markdown]
# #### Duplicate By SubsetColumn

# %%
phone_sale.loc[phone_sale.duplicated(subset=['Models'])]
# Out:
#       Brands           Models     Colors Memory                Storage Camera  \
# 11     Apple       iPhone 11         Red    4GB                 256 GB    Yes
# 16     Apple  iPhone 13 Mini        Pink   6 GB                 512 GB    Yes
# 34     Apple       iPhone 11       Green    4GB                  64 GB    Yes
# 49     Apple       iPhone 11       White    4GB                 256 GB    Yes
# 54     Apple       iPhone 11      Yellow    4GB                 256 GB    Yes
# ...      ...              ...        ...    ...                    ...    ...
# 3109    POCO        M4 Pro 5G  Cool Blue   6 GB                 128 GB    Yes
# 3110   Nokia              225      Black    NaN  Expandable Upto 32 GB    Yes
# 3111   Apple       iPhone SE       White   2 GB                 128 GB    Yes
# 3112   Apple   iPhone 13 Pro        Gold   6 GB                 128 GB    Yes
# 3113  GIONEE              F9        Blue   3 GB                  32 GB    Yes
#
# ...

# %%
phone_sale.query('Models == "iPhone 11 "')
# Out:
#      Brands      Models  Colors Memory Storage Camera  Rating  Selling Price  \
# 4     Apple  iPhone 11    Black    4GB   64 GB    Yes     4.6          49900
# 11    Apple  iPhone 11      Red    4GB  256 GB    Yes     4.6          64900
# 34    Apple  iPhone 11    Green    4GB   64 GB    Yes     4.6          49900
# 49    Apple  iPhone 11    White    4GB  256 GB    Yes     4.6          64900
# 54    Apple  iPhone 11   Yellow    4GB  256 GB    Yes     4.6          64900
# 178   Apple  iPhone 11    White    4GB  256 GB    Yes     4.6          64900
# 195   Apple  iPhone 11    White    4GB  128 GB    Yes     4.6          54900
# 298   Apple  iPhone 11      Red    4GB  128 GB    Yes     4.6          54900
# 421   Apple  iPhone 11    Black    4GB  128 GB    Yes     4.6          54900
# 1147  Apple  iPhone 11   Yellow    4GB  128 GB    Yes     4.6          54900
# 1247  Apple  iPhone 11      Red    4GB  256 GB    Yes     4.6          64900
# ...

# %% [markdown]
# ### Checking dan Drop Data Kosong

# %%
phone_sale.isnull().sum()
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# dtype: int64

# %%
phone_sale.dropna(inplace=True)

# %%
print(phone_sale.isnull().sum() )
print(phone_sale.shape)
# Out:
# Brands                 0
# Models                 0
# Colors                 0
# Memory                 0
# Storage                0
# Camera                 0
# Rating                 0
# Selling Price          0
# Original Price         0
# Mobile                 0
# Discount               0
# discount percentage    0
# dtype: int64
# (2897, 12)

# %%
phone_sale
# Out:
#        Brands            Models        Colors  Memory Storage Camera  Rating  \
# 0     SAMSUNG      GALAXY M31S   Mirage Black    8 GB  128 GB    Yes     4.3
# 1       Nokia               3.2         Steel    2 GB   16 GB    Yes     3.8
# 3     Infinix            Note 5      Ice Blue    4 GB   64 GB    Yes     4.2
# 4       Apple        iPhone 11          Black     4GB   64 GB    Yes     4.6
# 5      GIONEE              L800         Black    8 MB   16 MB    Yes     4.0
# ...       ...               ...           ...     ...     ...    ...     ...
# 3107  SAMSUNG  Galaxy S Duos 2          Black  512 MB    4 GB    Yes     4.0
# 3108  SAMSUNG         Metro 313         Black    4 MB    2 MB    Yes     4.2
# 3109     POCO         M4 Pro 5G     Cool Blue    6 GB  128 GB    Yes     4.4
# 3111    Apple        iPhone SE          White    2 GB  128 GB    Yes     4.5
# 3113   GIONEE               F9           Blue    3 GB   32 GB    Yes     4.2
#
# ...

# %% [markdown]
# ## 3. Features Understanding

# %% [markdown]
# ### Perhitungan Banyaknya Items

# %%
phone_sale['Brands'].value_counts()
# Out:
# Brands
# SAMSUNG         685
# Apple           319
# realme          281
# OPPO            251
# Xiaomi          191
# Nokia           184
# Infinix         151
# GIONEE          127
# Lenovo          120
# vivo            114
# ASUS            111
# Motorola        103
# LG               98
# POCO             73
# HTC              55
# Google Pixel     29
# IQOO              5
# Name: count, dtype: int64

# %% [markdown]
# ### Bar Chart

# %%
ax = phone_sale['Brands'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Brands Sales')
ax.set_xlabel('Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Histogram

# %%
ax = phone_sale['Rating'].plot(kind='hist',
                          bins=20,
                          title='Ratings Distribution')
ax.set_xlabel('Ratings')
# Out:
# Text(0.5, 0, 'Ratings')

# %% [markdown]
# ### KDE Plot

# %%
ax = phone_sale['Rating'].plot(kind='kde',
                          title='Ratings Distribution')
ax.set_xlabel('Ratings')
# Out:
# Text(0.5, 0, 'Ratings')

# %%
phone_sale['Mobile'].value_counts()
# Out:
# Mobile
# Apple iPhone 11         36
# Apple iPhone XR         27
# Apple iPhone 7          21
# Apple iPhone 11 Pro     21
# Apple iPhone 7 Plus     20
#                         ..
# GIONEE G3                1
# Motorola Edge+           1
# LG V40 ThinQ             1
# LG Nexus4 E960           1
# LG Q Stylus              1
# Name: count, Length: 891, dtype: int64

# %% [markdown]
# ## 4. Feature relationship

# %% [markdown]
# ### Scatterplot

# %%
phone_sale.plot(kind='scatter',
        x='Rating',
        y='Original Price',
        title='Rating vs. Price')
plt.show()

# %%
ax = sns.scatterplot(x='Rating',
                y='Original Price',
                hue='Brands',
                data=phone_sale)
ax.set_title('Rating vs. Price')
plt.show()

# %% [markdown]
# ### Correlation & Heatmap

# %%
phone_sale_corr = phone_sale[['Rating','Original Price']].dropna().corr()
phone_sale_corr
# Out:
#                   Rating  Original Price
# Rating          1.000000        0.450786
# Original Price  0.450786        1.000000

# %%
sns.heatmap(phone_sale_corr, annot=True)
# Out:
# <Axes: >
